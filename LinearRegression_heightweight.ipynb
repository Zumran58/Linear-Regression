# %% [markdown]
# # Welcome to Jupyter!

# %%
# How to build a linear regression model with python

# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
#Load dataset

data=pd.read_csv('/home/jovyan/binder/weight-height.csv')

# %%
data
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
data.shape
# Out:
# (10000, 3)

# %%
data.plot(kind='scatter', x='Height', y='Weight')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
data.plot(kind='box')

plt.show()

# %%
data.corr() #Correlation coefficients
# Out:
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000

# %%
#change to dataframe variable 

height=pd.DataFrame(data['Height'])

weight=pd.DataFrame(data['Weight'])

# %%
height
# Out:
#          Height
# 0     73.847017
# 1     68.781904
# 2     74.110105
# 3     71.730978
# 4     69.881796
# ...         ...
# 9995  66.172652
# 9996  67.067155
# 9997  63.867992
# 9998  69.034243
# 9999  61.944246
#
# [10000 rows x 1 columns]

# %%
#build a linear regression model

lm=linear_model.LinearRegression()
model=lm.fit(height, weight)

# %%
model.coef_
# Out:
# array([[7.71728764]])

# %%
model.intercept_
# Out:
# array([-350.73719181])

# %%
model.score(height, weight) #evalutate the model
# Out:
# 0.8551742120609958

# %%
#Predict new value of weight

height_new=71

weight_predict=model.predict(height)

weight_predict
# Out:
# array([[219.16147993],
#        [180.07254619],
#        [221.19180859],
#        ...,
#        [142.15047514],
#        [182.01991949],
#        [127.30437133]])

# %%
#Predict monde values

X=([67, 78, 94])
X=pd.DataFrame(X)
Y=model.predict(X)
Y=pd.DataFrame(Y)
df=pd.concat([X,Y], axis=1, keys=['height_new', 'weight_predict'])
df
# Out:
#   height_new weight_predict
#            0              0
# 0         67     166.321080
# 1         78     251.211244
# 2         94     374.687846

# %%
#visualize the result
data.plot(kind='scatter', x='Height', y='Weight')
#plotting the regression line
plt.plot(height, model.predict(height), color='red', linewidth=2)
#plotting the predict value

plt.show()
